# %% [markdown]
# # Handin 5
#
# We'll see how we can move a shape in the plane to a standard position.
#
# Consider the figure-eight plotted by
#
# $$x(t)=3cos(t),\ y(t) = sin(2t),\ \ \ for\ 0\leq t \leq 2\pi$$

# %% [markdown]
# ## (a) Plot the curve $(x(t), y(t))$

# %%
import numpy as np
import matplotlib.pyplot as plt

tMin = 0;
tMax = 2 * np.pi;

def x(t):
    return np.cos(t) * 3

def y(t):
    return np.sin(2*t)

lin = np.linspace(tMin, tMax, 100)
xs = x(lin)
ys = y(lin)

fig, ax = plt.subplots()
ax.set_aspect('equal')
ax.plot(xs,ys)

# %% [markdown]
# ## (b) Use the following snippet to rotate the figure-eight

# %%
rng = np.random.default_rng()
theta = rng.uniform(np.pi/5, 5 * np.pi/5)
print(theta)
# Out:
# 2.7381314886150077

# %%
R = np.array([[np.cos(theta), -np.sin(theta)],[np.sin(theta),np.cos(theta)]])
print(R)
# Out:
# [[-0.91970764 -0.39260395]
#  [ 0.39260395 -0.91970764]]

# %%
f = np.array([xs,ys])
# Rotate the figure
Rf = R@f

fig, ax = plt.subplots()
ax.set_aspect('equal')
ax.plot(Rf[0], Rf[1])

# %% [markdown]
# ## (c) Pick some points from the rotate figure and add some noise to it. Plot the result

# %% [markdown]
# I will create a function that will draw points from the rotated figure randomly.

# %%
def randomPoints(n):
    points = np.empty((2,n))
    i = 0;
    j = 0;
    while(i < n):
        rand = rng.uniform(0.,1.)
        if (rand < .5):
            safeJ = j % Rf.shape[1]
            xVal = Rf[0][safeJ]
            yVal = Rf[1][safeJ]
            points[0][i] = xVal
            points[1][i] = yVal
            i += 1
        j += 1
    return points

# %% [markdown]
# Then we use the rng.normal function to create some noise and add it to the selection of points.

# %%
n = 1000
noise = rng.normal(0.,0.1,(2, n))
A = randomPoints(n) + noise

# %% [markdown]
# Then we plot the result.

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')
ax.plot(A[0], A[1])

# %% [markdown]
# ## (d) For each row subract the mean to create a matrix $B$
# To do this, I create a function meanSubtraction

# %%
def meanSubtraction(_matrix):
    matrix = np.copy(_matrix)
    xMean = np.mean(matrix[0])
    yMean = np.mean(matrix[1])
    for i in range(matrix.shape[1]):
        matrix[0][i] += -xMean
        matrix[1][i] += -yMean
    return matrix

# %% [markdown]
# Then we will create the matrix $B$

# %%
B = meanSubtraction(A)

# %% [markdown]
# ## (e) Compute the SVD for B and print $U\in \mathbb{R}^{2\times 2}$ and the singular values.

# %%
u, s, vt = np.linalg.svd(B, full_matrices = False)

# %%
print("U = ", u)
print("")
print("sigma = ", s)
print("")
print("vt = ", vt)
# Out:
# U =  [[-0.91630446  0.40048237]
#  [ 0.40048237  0.91630446]]
#
# sigma =  [66.23564749 22.26882282]
#
# vt =  [[ 4.43792823e-02  4.29535851e-02  4.24327157e-02 ...  4.28727825e-02
#    4.40126477e-02  4.33096218e-02]
#  [ 4.58985672e-04 -5.86707302e-03 -1.89233339e-02 ... -2.66503260e-03
#   -6.48049220e-05 -2.46186756e-02]]

# %% [markdown]
# Describe how $U$ and $\Sigma$ are related to the original figure.

# %%
u, s, vt = np.linalg.svd(A, full_matrices = False)

# %%
print("U = ", u)
print("")
print("sigma = ", s)
print("")
print("vt = ", vt)
# Out:
# U =  [[-0.91630219  0.40048758]
#  [ 0.40048758  0.91630219]]
#
# sigma =  [66.24602178 22.26883082]
#
# vt =  [[ 4.49319585e-02  4.35064724e-02  4.29856596e-02 ...  4.34256886e-02
#    4.45653802e-02  4.38624175e-02]
#  [ 4.85026512e-04 -5.84100580e-03 -1.88972532e-02 ... -2.63896517e-03
#   -3.87576958e-05 -2.45926077e-02]]
